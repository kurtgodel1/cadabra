# %%
import pickle
import numpy as np
import scipy as sc
import sympy as sp
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

with open("output.pkl", "rb") as file:
   dVr=pickle.load(file)
   dVp=pickle.load(file)

dVp
# Out:
# 2*V1*V3*(3*M - r)/(r*(-2*M + r))

# %%
dvr = sp.lambdify((sp.Symbol("V1"), sp.Symbol("V3"), sp.Symbol("r"), sp.Symbol("M")), dVr, "numpy")
dvp = sp.lambdify((sp.Symbol("V1"), sp.Symbol("V3"), sp.Symbol("r"), sp.Symbol("M")), dVp, "numpy")

# %%
def geodesic(t, state):
    r, theta, phi, V1, V2, V3 = state

    dr = V1
    dth = 0
    dph = V3
    dV1 = dvr(V1,V3,r,1)
    dV2 = 0
    dV3 = dvp(V1,V3,r,1)

    return np.array([dr, dth, dph, dV1, dV2, dV3])

# %%
y0 = np.array([20, np.pi/2, 0, -0.1, 0 , 0.01])

t = 10000
scale = int(t/1000)
M=1

t_span = (0.0, t)
t_eval = np.linspace(0,t,t+1)

# %%
result_solve_ivp = sc.integrate.solve_ivp(geodesic, t_span, y0, rtol=1e-14, atol=1e-15, method='RK45',t_eval=t_eval)
# Out:
# /Users/aliosmanyilmaz/opt/anaconda3/lib/python3.9/site-packages/scipy/integrate/_ivp/common.py:47: UserWarning: At least one element of `rtol` is too small. Setting `rtol = np.maximum(rtol, 2.220446049250313e-14)`.
#   warn("At least one element of `rtol` is too small. "
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'Symbol' object has no attribute 'sin'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 result_solve_ivp = sc.integrate.solve_ivp(geodesic, t_span, y0, rtol=1e-14, atol=1e-15, method='RK45',t_eval=t_eval)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/scipy/integrate/_ivp/ivp.py:557, in solve_ivp(fun, t_span, y0, method, t_eval, dense_output, events, vectorized, args, **options)
#     554 if method in METHODS:
#     555     method = METHODS[method]
# --> 557 solver = method(fun, t0, y0, tf, vectorized=vectorized, **options)
#     559 if t_eval is None:
#     560     ts = [t0]
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/scipy/integrate/_ivp/rk.py:94, in RungeKutta.__init__(self, fun, t0, y0, t_bound, max_step, rtol, atol, vectorized, first_step, **extraneous)
#      92 self.max_step = validate_max_step(max_step)
#      93 self.rtol, self.atol = validate_tol(rtol, atol, self.n)
# ---> 94 self.f = self.fun(self.t, self.y)
#      95 if first_step is None:
#      96     self.h_abs = select_initial_step(
#      97         self.fun, self.t, self.y, self.f, self.direction,
#      98         self.error_estimator_order, self.rtol, self.atol)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/scipy/integrate/_ivp/base.py:138, in OdeSolver.__init__.<locals>.fun(t, y)
#     136 def fun(t, y):
#     137     self.nfev += 1
# --> 138     return self.fun_single(t, y)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/scipy/integrate/_ivp/base.py:20, in check_arguments.<locals>.fun_wrapped(t, y)
#      19 def fun_wrapped(t, y):
# ---> 20     return np.asarray(fun(t, y), dtype=dtype)
#
# Cell In[3], line 7, in geodesic(t, state)
#       5 dth = 0
#       6 dph = V3
# ----> 7 dV1 = dvr(V1,V3,r,1)
#       8 dV2 = 0
#       9 dV3 = dvp(V1,V3,r,1)
#
# File <lambdifygenerated-1>:2, in _lambdifygenerated(V1, V3, r, M)
#       1 def _lambdifygenerated(V1, V3, r, M):
# ----> 2     return (-3*M*V1**2*r**2 + M*(2*M - r)**2 - r**3*(2*M - r)**2*(V2**2 + V3**2*sin(theta)**2))/(r**3*(2*M - r))
#
# TypeError: loop of ufunc does not support argument 0 of type Symbol which has no callable sin method

# %%
r = result_solve_ivp.y[0]
theta = result_solve_ivp.y[1]
phi = result_solve_ivp.y[2]

# %%
x = r * np.sin(theta) * np.cos(phi)
y = r * np.sin(theta) * np.sin(phi)
z = r * np.cos(theta)

# %%
# %matplotlib widget
bh_r = 2*M

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
plt.cla()

bh_phi, bh_theta = np.mgrid[0:np.pi:101j, 0:2 * np.pi:101j]
bh_x = bh_r * np.sin(bh_phi) * np.cos(bh_theta)
bh_y = bh_r * np.sin(bh_phi) * np.sin(bh_theta)
bh_z = bh_r * np.cos(bh_phi)

bh = ax.plot_surface(bh_x,bh_y,bh_z,color='k')

q,= ax.plot(x,
        y,
        z, linewidth=.2)

ax.set_title("solve_ivp")
plt.xlabel("x")
plt.ylabel("y")
ax.view_init(elev=10, azim=-45)
ax.set_aspect('equal')
ax.grid(False)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
from matplotlib.animation import Animation, FuncAnimation, writers
from IPython import display


frm = 150
scale = int(len(x)/frm)-1

spheres = np.empty(frm, dtype=object)

ax.set_title("Black Hole")
plt.xlabel("x")
plt.ylabel("y")

def animation_function(ii):
    if ii==0:
        return
    if ii>1:
        spheres[ii-1].set_visible(False)
    #plt.cla()
    #ax.view_init(elev=0, azim=90)
    spheres[ii], = ax.plot(x[scale*ii],
                    y[scale*ii],
                    z[scale*ii], 'bo')


    

    #plt.axis("off")

    # plt.show()


anim = FuncAnimation(fig, animation_function, frames=frm, repeat=False, interval=100)
# converting to an html5 video
video = anim.to_html5_video()

# embedding for the video
html = display.HTML(video)

# draw the animation
display.display(html)
# Out:
# <video width="1280" height="960" controls autoplay>
#   <source type="video/mp4" src="...
